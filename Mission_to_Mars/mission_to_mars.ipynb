# %% [markdown]
# # web-scraping-challenge
#     by Diane Scherpereel      November 2019

# %%
# Dependencies
from bs4 import BeautifulSoup
import pandas as pd
import pymongo
import requests
from splinter import Browser

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %% [markdown]
# ### Nasa Mars News

# %%
# Define database and collection
nasa_db = client.nasa_db
nasa_collection = nasa_db.items

# %%
# URL of page to be scraped
url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'

# Retrieve page with the requests module
nasa_response = requests.get(url)
# Create BeautifulSoup object and parse
nasa_soup = BeautifulSoup(nasa_response.text, 'html.parser')

# %%
# Examine the results, then determine how to get the title and save it to the variable "nasa_news_title"
nasa_news_title_raw = nasa_soup.find(class_='content_title')
nasa_news_title = nasa_news_title_raw.text.strip()
nasa_news_title
# Out:
# 'NASA Invites Students to Name Mars 2020 Rover'

# %%
# Do the same to determine how to get the paragraph
nasa_paragraph_class = nasa_soup.find(class_="slide")
nasa_paragraph_class
# Out:
# <div class="slide">
# <div class="image_and_description_container">
# <a href="/news/8508/nasa-invites-students-to-name-mars-2020-rover/">
# <div class="rollover_description">
# <div class="rollover_description_inner">
# Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.
# </div>
# <div class="overlay_arrow">
# <img alt="More" src="/assets/overlay-arrow.png"/>
# </div>
# </div>
# <img alt="NASA Invites Students to Name Mars 2020 Rover" class="img-lazy" data-lazy="/system/news_items/list_view_images/8508_Name_A_unannotated_MAIN-th.jpg" src="/assets/loading_320x240.png"/>
# </a>
# </div>
# <div class="content_title">
# <a href="/news/8508/nasa-invites-students-to-name-mars-2020-rover/">
# NASA Invites Students to Name Mars 2020 Rover
# </a>
# </div>
# </div>

# %%
# Find and save the paragraph to the variable "nasa_paragraph"
nasa_paragraph_raw = nasa_soup.find(class_='rollover_description_inner')
nasa_paragraph = nasa_paragraph_raw.text.strip()
nasa_paragraph
# Out:
# "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."

# %% [markdown]
# ### JPL Mars Space Images

# %%
# Set up a chrome browser
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
jpl_url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(jpl_url)

# %%
# Create BeautifulSoup object and parse
jpl_html = browser.html
jpl_soup = BeautifulSoup(jpl_html, 'lxml')
# Select the part that contains the image urls
featured_image = jpl_soup.select('li.slide a.fancybox')
featured_image
# Out:
# [<a class="fancybox" data-description="This image from NASAs Mars Odyssey shows an unnamed crater located in Arabia Terra. The small crater seen in the image is located on the floor of a much larger crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23537_hires.jpg" data-link="/spaceimages/details.php?id=PIA23537" data-thumbnail="/spaceimages/images/wallpaper/PIA23537-640x350.jpg" data-title="Terraced Wall Crater">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 5, 2019</h3>
#  <div class="item_tease_overlay">Terraced Wall Crater</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Terraced Wall Crater" class="thumb" src="/spaceimages/images/wallpaper/PIA23537-640x350.jpg" title="Terraced Wall Crater"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 5, 2019</div>
#  <div class="content_title">
#  										  Terraced Wall Crater
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows an unnamed crater located in Arabia Terra. The small crater seen in the image is located on the floor of a much larger crater.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Lyot Crater, including a large field of sand dunes on the crater floor." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23536_hires.jpg" data-link="/spaceimages/details.php?id=PIA23536" data-thumbnail="/spaceimages/images/wallpaper/PIA23536-640x350.jpg" data-title="Lyot Crater Dunes">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 4, 2019</h3>
#  <div class="item_tease_overlay">Lyot Crater Dunes</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Lyot Crater Dunes" class="thumb" src="/spaceimages/images/wallpaper/PIA23536-640x350.jpg" title="Lyot Crater Dunes"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 4, 2019</div>
#  <div class="content_title">
#  										  Lyot Crater Dunes
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Lyot Crater, including a large field of sand dunes on the crater floor.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Chincoteague Crater. Chincoteague Crater is located in Utopia Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23525_hires.jpg" data-link="/spaceimages/details.php?id=PIA23525" data-thumbnail="/spaceimages/images/wallpaper/PIA23525-640x350.jpg" data-title="Chincoteague Crater">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 1, 2019</h3>
#  <div class="item_tease_overlay">Chincoteague Crater</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Chincoteague Crater" class="thumb" src="/spaceimages/images/wallpaper/PIA23525-640x350.jpg" title="Chincoteague Crater"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 1, 2019</div>
#  <div class="content_title">
#  										  Chincoteague Crater
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Chincoteague Crater. Chincoteague Crater is located in Utopia Planitia.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows one of the linear depressions that form Nili Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23524_hires.jpg" data-link="/spaceimages/details.php?id=PIA23524" data-thumbnail="/spaceimages/images/wallpaper/PIA23524-640x350.jpg" data-title="Nili Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 31, 2019</h3>
#  <div class="item_tease_overlay">Nili Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Nili Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23524-640x350.jpg" title="Nili Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 31, 2019</div>
#  <div class="content_title">
#  										  Nili Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows one of the linear depressions that form Nili Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Aronatum Chaos. Aromatum Chaos is a depression about 90 km (56 mi) long by 30 km (20 mi) wide." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23523_hires.jpg" data-link="/spaceimages/details.php?id=PIA23523" data-thumbnail="/spaceimages/images/wallpaper/PIA23523-640x350.jpg" data-title="Aromatum Chaos">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 30, 2019</h3>
#  <div class="item_tease_overlay">Aromatum Chaos</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Aromatum Chaos" class="thumb" src="/spaceimages/images/wallpaper/PIA23523-640x350.jpg" title="Aromatum Chaos"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 30, 2019</div>
#  <div class="content_title">
#  										  Aromatum Chaos
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Aronatum Chaos. Aromatum Chaos is a depression about 90 km (56 mi) long by 30 km (20 mi) wide.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a channel located on the western margin of Medusae Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23522_hires.jpg" data-link="/spaceimages/details.php?id=PIA23522" data-thumbnail="/spaceimages/images/wallpaper/PIA23522-640x350.jpg" data-title="Medusae Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 29, 2019</h3>
#  <div class="item_tease_overlay">Medusae Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Medusae Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23522-640x350.jpg" title="Medusae Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 29, 2019</div>
#  <div class="content_title">
#  										  Medusae Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a channel located on the western margin of Medusae Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a linear depression which is part of Idaeus Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23521_hires.jpg" data-link="/spaceimages/details.php?id=PIA23521" data-thumbnail="/spaceimages/images/wallpaper/PIA23521-640x350.jpg" data-title="Idaeus Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 28, 2019</h3>
#  <div class="item_tease_overlay">Idaeus Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Idaeus Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23521-640x350.jpg" title="Idaeus Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 28, 2019</div>
#  <div class="content_title">
#  										  Idaeus Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a linear depression which is part of Idaeus Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a backs="" class="fancybox" data-description="In this image from Oct. 26, 2019, InSights heat probe is seen after backing about halfway out of the hole it had burrowed." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23213_hires.jpg" data-link="/spaceimages/details.php?id=PIA23213" data-thumbnail="/spaceimages/images/wallpaper/PIA23213-640x350.jpg" data-title="InSight" heat="" hole="" of="" out="" partially="" probe="" s="">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 28, 2019</h3>
#  <div class="item_tease_overlay">InSight's Heat Probe Partially Backs Out of Hole</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="InSight" backs="" class="thumb" heat="" hole="" of="" out="" partially="" probe="" s="" src="/spaceimages/images/wallpaper/PIA23213-640x350.jpg" title="InSight"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 28, 2019</div>
#  <div class="content_title">
#  										  InSight's Heat Probe Partially Backs Out of Hole
#  										</div>
#  <div class="article_teaser_body">
#  										  In this image from Oct. 26, 2019, InSights heat probe is seen after backing about halfway out of the hole it had burrowed.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Indus Vallis. Indus Vallis is 300km long (186 miles) and is located in Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23510_hires.jpg" data-link="/spaceimages/details.php?id=PIA23510" data-thumbnail="/spaceimages/images/wallpaper/PIA23510-640x350.jpg" data-title="Indus Vallis">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 25, 2019</h3>
#  <div class="item_tease_overlay">Indus Vallis</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Indus Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23510-640x350.jpg" title="Indus Vallis"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 25, 2019</div>
#  <div class="content_title">
#  										  Indus Vallis
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Indus Vallis. Indus Vallis is 300km long (186 miles) and is located in Terra Sabaea.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="NASAs Curiosity rover took this selfie on Oct. 11, 2019, the 2,553rd Martian day, or sol, of its mission. The rover drilled twice in this location, which is nicknamed Glen Etive." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23378_hires.jpg" data-link="/spaceimages/details.php?id=PIA23378" data-thumbnail="/spaceimages/images/wallpaper/PIA23378-640x350.jpg" data-title="Curiosity at Glen Etive">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 24, 2019</h3>
#  <div class="item_tease_overlay">Curiosity at Glen Etive</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Curiosity at Glen Etive" class="thumb" src="/spaceimages/images/wallpaper/PIA23378-640x350.jpg" title="Curiosity at Glen Etive"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 24, 2019</div>
#  <div class="content_title">
#  										  Curiosity at Glen Etive
#  										</div>
#  <div class="article_teaser_body">
#  										  NASAs Curiosity rover took this selfie on Oct. 11, 2019, the 2,553rd Martian day, or sol, of its mission. The rover drilled twice in this location, which is nicknamed Glen Etive.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the complex interior of an unnamed crater in Arabia Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23509_hires.jpg" data-link="/spaceimages/details.php?id=PIA23509" data-thumbnail="/spaceimages/images/wallpaper/PIA23509-640x350.jpg" data-title="Dark Slope Streaks">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 24, 2019</h3>
#  <div class="item_tease_overlay">Dark Slope Streaks</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Dark Slope Streaks" class="thumb" src="/spaceimages/images/wallpaper/PIA23509-640x350.jpg" title="Dark Slope Streaks"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 24, 2019</div>
#  <div class="content_title">
#  										  Dark Slope Streaks
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows the complex interior of an unnamed crater in Arabia Terra.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows two channels, visible at the top of this image, that are tributaries of Indus Vallis." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23508_hires.jpg" data-link="/spaceimages/details.php?id=PIA23508" data-thumbnail="/spaceimages/images/wallpaper/PIA23508-640x350.jpg" data-title="Indus Vallis Tributaries">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 23, 2019</h3>
#  <div class="item_tease_overlay">Indus Vallis Tributaries</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Indus Vallis Tributaries" class="thumb" src="/spaceimages/images/wallpaper/PIA23508-640x350.jpg" title="Indus Vallis Tributaries"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 23, 2019</div>
#  <div class="content_title">
#  										  Indus Vallis Tributaries
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows two channels, visible at the top of this image, that are tributaries of Indus Vallis.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the southeastern portion of Hephaestus Fossae. Hephaestus Fossae is a complex channel system in Utopia Planitia near Elysium Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23507_hires.jpg" data-link="/spaceimages/details.php?id=PIA23507" data-thumbnail="/spaceimages/images/wallpaper/PIA23507-640x350.jpg" data-title="Hephaestus Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 22, 2019</h3>
#  <div class="item_tease_overlay">Hephaestus Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Hephaestus Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23507-640x350.jpg" title="Hephaestus Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 22, 2019</div>
#  <div class="content_title">
#  										  Hephaestus Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows the southeastern portion of Hephaestus Fossae. Hephaestus Fossae is a complex channel system in Utopia Planitia near Elysium Mons.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image, acquired on October 26, 2017 by NASAs Mars Reconnaissance Orbiter, shows a cross-section of ancient canyon systems in east Coprates Chasma." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23530_hires.jpg" data-link="/spaceimages/details.php?id=PIA23530" data-thumbnail="/spaceimages/images/wallpaper/PIA23530-640x350.jpg" data-title="Enigmatic Canyon Dunes">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 21, 2019</h3>
#  <div class="item_tease_overlay">Enigmatic Canyon Dunes</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Enigmatic Canyon Dunes" class="thumb" src="/spaceimages/images/wallpaper/PIA23530-640x350.jpg" title="Enigmatic Canyon Dunes"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 21, 2019</div>
#  <div class="content_title">
#  										  Enigmatic Canyon Dunes
#  										</div>
#  <div class="article_teaser_body">
#  										  This image, acquired on October 26, 2017 by NASAs Mars Reconnaissance Orbiter, shows a cross-section of ancient canyon systems in east Coprates Chasma.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image, acquired on August 11, 2019 by NASAs Mars Reconnaissance Orbiter, shows wind-blown deposits known as transverse aeolian ridges (TARs). They are frequently visible in images of the Martian tropics." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23529_hires.jpg" data-link="/spaceimages/details.php?id=PIA23529" data-thumbnail="/spaceimages/images/wallpaper/PIA23529-640x350.jpg" data-title="Pristine Dust Deposits in Syria Planum">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 21, 2019</h3>
#  <div class="item_tease_overlay">Pristine Dust Deposits in Syria Planum</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Pristine Dust Deposits in Syria Planum" class="thumb" src="/spaceimages/images/wallpaper/PIA23529-640x350.jpg" title="Pristine Dust Deposits in Syria Planum"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 21, 2019</div>
#  <div class="content_title">
#  										  Pristine Dust Deposits in Syria Planum
#  										</div>
#  <div class="article_teaser_body">
#  										  This image, acquired on August 11, 2019 by NASAs Mars Reconnaissance Orbiter, shows wind-blown deposits known as transverse aeolian ridges (TARs). They are frequently visible in images of the Martian tropics.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image, acquired on July 28, 2019 by NASAs Mars Reconnaissance Orbiter, shows Chukhung, a 45 kilometer-diameter, central pit crater in Tempe Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23528_hires.jpg" data-link="/spaceimages/details.php?id=PIA23528" data-thumbnail="/spaceimages/images/wallpaper/PIA23528-640x350.jpg" data-title="Down in Chukhung Crater">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 21, 2019</h3>
#  <div class="item_tease_overlay">Down in Chukhung Crater</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Down in Chukhung Crater" class="thumb" src="/spaceimages/images/wallpaper/PIA23528-640x350.jpg" title="Down in Chukhung Crater"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 21, 2019</div>
#  <div class="content_title">
#  										  Down in Chukhung Crater
#  										</div>
#  <div class="article_teaser_body">
#  										  This image, acquired on July 28, 2019 by NASAs Mars Reconnaissance Orbiter, shows Chukhung, a 45 kilometer-diameter, central pit crater in Tempe Terra.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image, acquired on July 16, 2019 by NASAs Mars Reconnaissance Orbiter, shows the polar region, in the Northern Hemisphere of Mars, is still blanketed by seasonal carbon dioxide frost (dry ice)." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23527_hires.jpg" data-link="/spaceimages/details.php?id=PIA23527" data-thumbnail="/spaceimages/images/wallpaper/PIA23527-640x350.jpg" data-title="A Martian Game Board">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 21, 2019</h3>
#  <div class="item_tease_overlay">A Martian Game Board</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="A Martian Game Board" class="thumb" src="/spaceimages/images/wallpaper/PIA23527-640x350.jpg" title="A Martian Game Board"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 21, 2019</div>
#  <div class="content_title">
#  										  A Martian Game Board
#  										</div>
#  <div class="article_teaser_body">
#  										  This image, acquired on July 16, 2019 by NASAs Mars Reconnaissance Orbiter, shows the polar region, in the Northern Hemisphere of Mars, is still blanketed by seasonal carbon dioxide frost (dry ice).
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Athabasca Valles. The tear shaped features in the image are called streamlined islands." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23506_hires.jpg" data-link="/spaceimages/details.php?id=PIA23506" data-thumbnail="/spaceimages/images/wallpaper/PIA23506-640x350.jpg" data-title="Athabasca Valles">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 21, 2019</h3>
#  <div class="item_tease_overlay">Athabasca Valles</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Athabasca Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23506-640x350.jpg" title="Athabasca Valles"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 21, 2019</div>
#  <div class="content_title">
#  										  Athabasca Valles
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Athabasca Valles. The tear shaped features in the image are called streamlined islands.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows Uranius Fossae, a region of multi directional graben." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23505_hires.jpg" data-link="/spaceimages/details.php?id=PIA23505" data-thumbnail="/spaceimages/images/wallpaper/PIA23505-640x350.jpg" data-title="Uranius Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 18, 2019</h3>
#  <div class="item_tease_overlay">Uranius Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Uranius Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23505-640x350.jpg" title="Uranius Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 18, 2019</div>
#  <div class="content_title">
#  										  Uranius Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows Uranius Fossae, a region of multi directional graben.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This animation shows NASA InSights heat probe, or mole, digging about a centimeter (half an inch) below the surface." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23379_hires.jpg" data-link="/spaceimages/details.php?id=PIA23379" data-thumbnail="/spaceimages/images/wallpaper/PIA23379-640x350.jpg" data-title="Pinning Helps the Mole Move">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 17, 2019</h3>
#  <div class="item_tease_overlay">Pinning Helps the Mole Move</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Pinning Helps the Mole Move" class="thumb" src="/spaceimages/images/wallpaper/PIA23379-640x350.jpg" title="Pinning Helps the Mole Move"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 17, 2019</div>
#  <div class="content_title">
#  										  Pinning Helps the Mole Move
#  										</div>
#  <div class="article_teaser_body">
#  										  This animation shows NASA InSights heat probe, or mole, digging about a centimeter (half an inch) below the surface.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Elysium Fossae, located on the western flank of the Elysium volcanic complex." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23504_hires.jpg" data-link="/spaceimages/details.php?id=PIA23504" data-thumbnail="/spaceimages/images/wallpaper/PIA23504-640x350.jpg" data-title="Elysium Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 17, 2019</h3>
#  <div class="item_tease_overlay">Elysium Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Elysium Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23504-640x350.jpg" title="Elysium Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 17, 2019</div>
#  <div class="content_title">
#  										  Elysium Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Elysium Fossae, located on the western flank of the Elysium volcanic complex.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This animation shows the position of NASAs Curiosity rover as it journeyed through the clay-bearing unit on Mars between May 31 and July 20, 2019. The HiRISE camera on NASAs Mars Reconnaissance Orbiter took both images." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23377_hires.jpg" data-link="/spaceimages/details.php?id=PIA23377" data-thumbnail="/spaceimages/images/wallpaper/PIA23377-640x350.jpg" data-title="HiRISE Watches Curiosity Journey Across the Clay Unit">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 16, 2019</h3>
#  <div class="item_tease_overlay">HiRISE Watches Curiosity Journey Across the Clay Unit</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="HiRISE Watches Curiosity Journey Across the Clay Unit" class="thumb" src="/spaceimages/images/wallpaper/PIA23377-640x350.jpg" title="HiRISE Watches Curiosity Journey Across the Clay Unit"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 16, 2019</div>
#  <div class="content_title">
#  										  HiRISE Watches Curiosity Journey Across the Clay Unit
#  										</div>
#  <div class="article_teaser_body">
#  										  This animation shows the position of NASAs Curiosity rover as it journeyed through the clay-bearing unit on Mars between May 31 and July 20, 2019. The HiRISE camera on NASAs Mars Reconnaissance Orbiter took both images.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="The HiRISE camera on NASAs Mars Reconnaissance Orbiter got its best view yet of the InSight lander on September 23, 2019." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23376_hires.jpg" data-link="/spaceimages/details.php?id=PIA23376" data-thumbnail="/spaceimages/images/wallpaper/PIA23376-640x350.jpg" data-title="The Best View of InSight">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 16, 2019</h3>
#  <div class="item_tease_overlay">The Best View of InSight</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="The Best View of InSight" class="thumb" src="/spaceimages/images/wallpaper/PIA23376-640x350.jpg" title="The Best View of InSight"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 16, 2019</div>
#  <div class="content_title">
#  										  The Best View of InSight
#  										</div>
#  <div class="article_teaser_body">
#  										  The HiRISE camera on NASAs Mars Reconnaissance Orbiter got its best view yet of the InSight lander on September 23, 2019.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows linear depressions, graben, that are called Cerberus Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23503_hires.jpg" data-link="/spaceimages/details.php?id=PIA23503" data-thumbnail="/spaceimages/images/wallpaper/PIA23503-640x350.jpg" data-title="Cerberus Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 16, 2019</h3>
#  <div class="item_tease_overlay">Cerberus Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Cerberus Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23503-640x350.jpg" title="Cerberus Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 16, 2019</div>
#  <div class="content_title">
#  										  Cerberus Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows linear depressions, graben, that are called Cerberus Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a small section of an unnamed channel in Arabia Terra. This is just one of many channels dissecting the region." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23502_hires.jpg" data-link="/spaceimages/details.php?id=PIA23502" data-thumbnail="/spaceimages/images/wallpaper/PIA23502-640x350.jpg" data-title="Arabia Terra Channel">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 15, 2019</h3>
#  <div class="item_tease_overlay">Arabia Terra Channel</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Arabia Terra Channel" class="thumb" src="/spaceimages/images/wallpaper/PIA23502-640x350.jpg" title="Arabia Terra Channel"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 15, 2019</div>
#  <div class="content_title">
#  										  Arabia Terra Channel
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a small section of an unnamed channel in Arabia Terra. This is just one of many channels dissecting the region.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows Olympica Fossae, a complex channel located on the Tharsis volcanic plains between Alba Mons and Olympus Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23501_hires.jpg" data-link="/spaceimages/details.php?id=PIA23501" data-thumbnail="/spaceimages/images/wallpaper/PIA23501-640x350.jpg" data-title="Olympica Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 14, 2019</h3>
#  <div class="item_tease_overlay">Olympica Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Olympica Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23501-640x350.jpg" title="Olympica Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 14, 2019</div>
#  <div class="content_title">
#  										  Olympica Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows Olympica Fossae, a complex channel located on the Tharsis volcanic plains between Alba Mons and Olympus Mons.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a location in Terra Cimmeria, near the margin with Nepenthes Mensae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23489_hires.jpg" data-link="/spaceimages/details.php?id=PIA23489" data-thumbnail="/spaceimages/images/wallpaper/PIA23489-640x350.jpg" data-title="Terra Cimmeria">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 11, 2019</h3>
#  <div class="item_tease_overlay">Terra Cimmeria</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Terra Cimmeria" class="thumb" src="/spaceimages/images/wallpaper/PIA23489-640x350.jpg" title="Terra Cimmeria"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 11, 2019</div>
#  <div class="content_title">
#  										  Terra Cimmeria
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a location in Terra Cimmeria, near the margin with Nepenthes Mensae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the floor of Lyot Crater, including a field of dunes." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23488_hires.jpg" data-link="/spaceimages/details.php?id=PIA23488" data-thumbnail="/spaceimages/images/wallpaper/PIA23488-640x350.jpg" data-title="Lyot Crater Dunes">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 10, 2019</h3>
#  <div class="item_tease_overlay">Lyot Crater Dunes</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Lyot Crater Dunes" class="thumb" src="/spaceimages/images/wallpaper/PIA23488-640x350.jpg" title="Lyot Crater Dunes"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 10, 2019</div>
#  <div class="content_title">
#  										  Lyot Crater Dunes
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the floor of Lyot Crater, including a field of dunes.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the southern rim of Cerulli Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23487_hires.jpg" data-link="/spaceimages/details.php?id=PIA23487" data-thumbnail="/spaceimages/images/wallpaper/PIA23487-640x350.jpg" data-title="Cerulli Crater Rim">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 9, 2019</h3>
#  <div class="item_tease_overlay">Cerulli Crater Rim</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Cerulli Crater Rim" class="thumb" src="/spaceimages/images/wallpaper/PIA23487-640x350.jpg" title="Cerulli Crater Rim"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 9, 2019</div>
#  <div class="content_title">
#  										  Cerulli Crater Rim
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the southern rim of Cerulli Crater.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Nilus Mensae, a complex region of tectonic faulting and fluid flow features." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23486_hires.jpg" data-link="/spaceimages/details.php?id=PIA23486" data-thumbnail="/spaceimages/images/wallpaper/PIA23486-640x350.jpg" data-title="Nilus Mensae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 8, 2019</h3>
#  <div class="item_tease_overlay">Nilus Mensae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Nilus Mensae" class="thumb" src="/spaceimages/images/wallpaper/PIA23486-640x350.jpg" title="Nilus Mensae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 8, 2019</div>
#  <div class="content_title">
#  										  Nilus Mensae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Nilus Mensae, a complex region of tectonic faulting and fluid flow features.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a portion of Olympia Undae, a large dune field located near the north pole." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23485_hires.jpg" data-link="/spaceimages/details.php?id=PIA23485" data-thumbnail="/spaceimages/images/wallpaper/PIA23485-640x350.jpg" data-title="Olympia Undae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 7, 2019</h3>
#  <div class="item_tease_overlay">Olympia Undae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Olympia Undae" class="thumb" src="/spaceimages/images/wallpaper/PIA23485-640x350.jpg" title="Olympia Undae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 7, 2019</div>
#  <div class="content_title">
#  										  Olympia Undae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a portion of Olympia Undae, a large dune field located near the north pole.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Ceraunius Fossae. The linear depressions are fault bounded features called graben." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23484_hires.jpg" data-link="/spaceimages/details.php?id=PIA23484" data-thumbnail="/spaceimages/images/wallpaper/PIA23484-640x350.jpg" data-title="Ceraunius Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">October 4, 2019</h3>
#  <div class="item_tease_overlay">Ceraunius Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Ceraunius Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23484-640x350.jpg" title="Ceraunius Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">October 4, 2019</div>
#  <div class="content_title">
#  										  Ceraunius Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Ceraunius Fossae. The linear depressions are fault bounded features called graben.
#  										</div>
#  </div>
#  </div>
#  </a>]

# %%
# Make a list of just the data-fancybox-hrefs
img_list = [i.get('data-fancybox-href') for i in featured_image]
img_list
# Out:
# ['/spaceimages/images/largesize/PIA23537_hires.jpg',
#  '/spaceimages/images/largesize/PIA23536_hires.jpg',
#  '/spaceimages/images/largesize/PIA23525_hires.jpg',
#  '/spaceimages/images/largesize/PIA23524_hires.jpg',
#  '/spaceimages/images/largesize/PIA23523_hires.jpg',
#  '/spaceimages/images/largesize/PIA23522_hires.jpg',
#  '/spaceimages/images/largesize/PIA23521_hires.jpg',
#  '/spaceimages/images/largesize/PIA23213_hires.jpg',
#  '/spaceimages/images/largesize/PIA23510_hires.jpg',
#  '/spaceimages/images/largesize/PIA23378_hires.jpg',
#  '/spaceimages/images/largesize/PIA23509_hires.jpg',
#  '/spaceimages/images/largesize/PIA23508_hires.jpg',
#  '/spaceimages/images/largesize/PIA23507_hires.jpg',
#  '/spaceimages/images/largesize/PIA23530_hires.jpg',
#  '/spaceimages/images/largesize/PIA23529_hires.jpg',
#  '/spaceimages/images/largesize/PIA23528_hires.jpg',
#  '/spaceimages/images/largesize/PIA23527_hires.jpg',
#  '/spaceimages/images/largesize/PIA23506_hires.jpg',
#  '/spaceimages/images/largesize/PIA23505_hires.jpg',
#  '/spaceimages/images/largesize/PIA23379_hires.jpg',
#  '/spaceimages/images/largesize/PIA23504_hires.jpg',
#  '/spaceimages/images/largesize/PIA23377_hires.jpg',
#  '/spaceimages/images/largesize/PIA23376_hires.jpg',
#  '/spaceimages/images/largesize/PIA23503_hires.jpg',
#  '/spaceimages/images/largesize/PIA23502_hires.jpg',
#  '/spaceimages/images/largesize/PIA23501_hires.jpg',
#  '/spaceimages/images/largesize/PIA23489_hires.jpg',
#  '/spaceimages/images/largesize/PIA23488_hires.jpg',
#  '/spaceimages/images/largesize/PIA23487_hires.jpg',
#  '/spaceimages/images/largesize/PIA23486_hires.jpg',
#  '/spaceimages/images/largesize/PIA23485_hires.jpg',
#  '/spaceimages/images/largesize/PIA23484_hires.jpg']

# %%
# Put just the base part of the webpage into a variable
img_base_url = 'https://www.jpl.nasa.gov'
# Combine the base url with the first img url from img_list
featured_image_url = img_base_url + img_list[0] 
featured_image_url
# Out:
# 'https://www.jpl.nasa.gov/spaceimages/images/largesize/PIA23537_hires.jpg'

# %% [markdown]
# ### Mars Weather

# %%
# Define database and collection
mars_weather_db = client.mars_weather_db
mars_weather_collection = mars_weather_db.items

# %%
# URL of page to be scraped
mars_weather_url = 'https://twitter.com/marswxreport?lang=en'

# Retrieve page with the requests module
mars_weather_response = requests.get(mars_weather_url)
# Create BeautifulSoup object and parse
mars_weather_soup = BeautifulSoup(mars_weather_response.text, 'html.parser')

# %%
# Find and save the latest tweet for Mars weather
mars_weather_raw = mars_weather_soup.find(class_='TweetTextSize')
mars_weather = mars_weather_raw.text.strip()
mars_weather
# Out:
# 'InSight sol 334 (2019-11-04) low -100.0ºC (-148.1ºF) high -23.8ºC (-10.8ºF)\nwinds from the SSW at 5.1 m/s (11.4 mph) gusting to 19.9 m/s (44.4 mph)\npressure at 7.00 hPapic.twitter.com/D4EX1MROay'

# %% [markdown]
# ### Mars Facts

# %%
# Label the mars facts url
mars_facts_url = 'https://space-facts.com/mars/'

# %%
# Use pandas to read the mars facts table
mars_facts_table = pd.read_html(mars_facts_url)
mars_facts_table
# Out:
# [                      0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
#  3                Moons:            2 (Phobos & Deimos)
#  4       Orbit Distance:       227,943,824 km (1.38 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                   -87 to -5 °C
#  7         First Record:              2nd millennium BC
#  8          Recorded By:           Egyptian astronomers,
#    Mars - Earth Comparison             Mars            Earth
#  0               Diameter:         6,779 km        12,742 km
#  1                   Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
#  2                  Moons:                2                1
#  3      Distance from Sun:   227,943,824 km   149,598,262 km
#  4         Length of Year:   687 Earth days      365.24 days
#  5            Temperature:    -153 to 20 °C      -88 to 58°C,
#                        0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
#  3                Moons:            2 (Phobos & Deimos)
#  4       Orbit Distance:       227,943,824 km (1.38 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                   -87 to -5 °C
#  7         First Record:              2nd millennium BC
#  8          Recorded By:           Egyptian astronomers]

# %%
# Check the type of the mars_facts_table
print(type(mars_facts_table))
# Out:
# <class 'list'>

# %%
# Put the table into a pandas dataframe
mars_facts_db1 = mars_facts_table[0]

# Set index to the 0 column
mars_facts_db1.set_index(0, inplace=True)

# Delete the index name ('0')
mars_facts_db1.index.names = [None]

# Delete the column name ('1')
mars_facts_db1.columns = ['']

mars_facts_db1
# Out:
#
# Equatorial Diameter:                       6,792 km
# Polar Diameter:                            6,752 km
# Mass:                 6.39 × 10^23 kg (0.11 Earths)
# Moons:                          2 (Phobos & Deimos)
# Orbit Distance:            227,943,824 km (1.38 AU)
# Orbit Period:                  687 days (1.9 years)
# Surface Temperature:                   -87 to -5 °C
# First Record:                     2nd millennium BC
# Recorded By:                   Egyptian astronomers

# %%
# Convert the pandas dataframe to HTML table string
mars_facts_html_table = mars_facts_db1.to_html()
mars_facts_html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Equatorial Diameter:</th>\n      <td>6,792 km</td>\n    </tr>\n    <tr>\n      <th>Polar Diameter:</th>\n      <td>6,752 km</td>\n    </tr>\n    <tr>\n      <th>Mass:</th>\n      <td>6.39 × 10^23 kg (0.11 Earths)</td>\n    </tr>\n    <tr>\n      <th>Moons:</th>\n      <td>2 (Phobos &amp; Deimos)</td>\n    </tr>\n    <tr>\n      <th>Orbit Distance:</th>\n      <td>227,943,824 km (1.38 AU)</td>\n    </tr>\n    <tr>\n      <th>Orbit Period:</th>\n      <td>687 days (1.9 years)</td>\n    </tr>\n    <tr>\n      <th>Surface Temperature:</th>\n      <td>-87 to -5 °C</td>\n    </tr>\n    <tr>\n      <th>First Record:</th>\n      <td>2nd millennium BC</td>\n    </tr>\n    <tr>\n      <th>Recorded By:</th>\n      <td>Egyptian astronomers</td>\n    </tr>\n  </tbody>\n</table>'

# %%
# Clean up the table by getting rid of these \n
mars_facts_html_table = mars_facts_html_table.replace('\n', '')
mars_facts_html_table
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>Equatorial Diameter:</th>      <td>6,792 km</td>    </tr>    <tr>      <th>Polar Diameter:</th>      <td>6,752 km</td>    </tr>    <tr>      <th>Mass:</th>      <td>6.39 × 10^23 kg (0.11 Earths)</td>    </tr>    <tr>      <th>Moons:</th>      <td>2 (Phobos &amp; Deimos)</td>    </tr>    <tr>      <th>Orbit Distance:</th>      <td>227,943,824 km (1.38 AU)</td>    </tr>    <tr>      <th>Orbit Period:</th>      <td>687 days (1.9 years)</td>    </tr>    <tr>      <th>Surface Temperature:</th>      <td>-87 to -5 °C</td>    </tr>    <tr>      <th>First Record:</th>      <td>2nd millennium BC</td>    </tr>    <tr>      <th>Recorded By:</th>      <td>Egyptian astronomers</td>    </tr>  </tbody></table>'

# %%
# There is also a comparison table between Mars and Earth - interesting but won't be used in the rest of this project. 
mars_earth_comparison = mars_facts_table[1]
mars_earth_comparison
# Out:
#   Mars - Earth Comparison             Mars            Earth
# 0               Diameter:         6,779 km        12,742 km
# 1                   Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 2                  Moons:                2                1
# 3      Distance from Sun:   227,943,824 km   149,598,262 km
# 4         Length of Year:   687 Earth days      365.24 days
# 5            Temperature:    -153 to 20 °C      -88 to 58°C

# %% [markdown]
# ### Mars Hemispheres

# %%
# Visit the USGS Astrogeology site to obtain high resolution images for each of Mars hemispheres
usgs_url = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
browser.visit(usgs_url)

# Create BeautifulSoup object and parse
soup = BeautifulSoup(browser.html, 'html.parser')

# %%
# Get the 4 hemispheres from div.item
hemispheres = soup.select('div.item')
hemispheres
# Out:
# [<div class="item"><a class="itemLink product-item" href="/search/map/Mars/Viking/cerberus_enhanced"><img alt="Cerberus Hemisphere Enhanced thumbnail" class="thumb" src="/cache/images/dfaf3849e74bf973b59eb50dab52b583_cerberus_enhanced.tif_thumb.png"/></a><div class="description"><a class="itemLink product-item" href="/search/map/Mars/Viking/cerberus_enhanced"><h3>Cerberus Hemisphere Enhanced</h3></a><span class="subtitle" style="float:left">image/tiff 21 MB</span><span class="pubDate" style="float:right"></span><br/><p>Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquired…</p></div> <!-- end description --></div>,
#  <div class="item"><a class="itemLink product-item" href="/search/map/Mars/Viking/schiaparelli_enhanced"><img alt="Schiaparelli Hemisphere Enhanced thumbnail" class="thumb" src="/cache/images/7677c0a006b83871b5a2f66985ab5857_schiaparelli_enhanced.tif_thumb.png"/></a><div class="description"><a class="itemLink product-item" href="/search/map/Mars/Viking/schiaparelli_enhanced"><h3>Schiaparelli Hemisphere Enhanced</h3></a><span class="subtitle" style="float:left">image/tiff 35 MB</span><span class="pubDate" style="float:right"></span><br/><p>Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northern…</p></div> <!-- end description --></div>,
#  <div class="item"><a class="itemLink product-item" href="/search/map/Mars/Viking/syrtis_major_enhanced"><img alt="Syrtis Major Hemisphere Enhanced thumbnail" class="thumb" src="/cache/images/aae41197e40d6d4f3ea557f8cfe51d15_syrtis_major_enhanced.tif_thumb.png"/></a><div class="description"><a class="itemLink product-item" href="/search/map/Mars/Viking/syrtis_major_enhanced"><h3>Syrtis Major Hemisphere Enhanced</h3></a><span class="subtitle" style="float:left">image/tiff 25 MB</span><span class="pubDate" style="float:right"></span><br/><p>Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violet…</p></div> <!-- end description --></div>,
#  <div class="item"><a class="itemLink product-item" href="/search/map/Mars/Viking/valles_marineris_enhanced"><img alt="Valles Marineris Hemisphere Enhanced thumbnail" class="thumb" src="/cache/images/04085d99ec3713883a9a57f42be9c725_valles_marineris_enhanced.tif_thumb.png"/></a><div class="description"><a class="itemLink product-item" href="/search/map/Mars/Viking/valles_marineris_enhanced"><h3>Valles Marineris Hemisphere Enhanced</h3></a><span class="subtitle" style="float:left">image/tiff 27 MB</span><span class="pubDate" style="float:right"></span><br/><p>Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of…</p></div> <!-- end description --></div>]

# %%
# Loop through each hemisphere

hemisphere_image_urls = []

for h in hemispheres:
    title = (h.find('h3').text).replace(' Enhanced', '')
        
    # click the hemisphere
    browser.click_link_by_partial_text(title)
    
    # make new soup of that page
    soup = BeautifulSoup(browser.html, 'html.parser')
    
    # find the full image
    full = soup.find('a', text='Sample')
    
    # get the img url
    img_url = full['href']
    
    # make a dictionary and append to the list
    hemisphere_image_urls.append({'title': title, 'img_url': img_url})
    
    # go back 
    browser.back()

# close the browser
browser.quit()    

hemisphere_image_urls
# Out:
# [{'title': 'Cerberus Hemisphere',
#   'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg'},
#  {'title': 'Schiaparelli Hemisphere',
#   'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif/full.jpg'},
#  {'title': 'Syrtis Major Hemisphere',
#   'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif/full.jpg'},
#  {'title': 'Valles Marineris Hemisphere',
#   'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg'}]
